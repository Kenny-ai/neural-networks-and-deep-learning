# %%
from src import mnist_loader
training_data, validation_data, test_data = mnist_loader.load_data_wrapper("data/mnist.pkl.gz")

# %%
from src import network2
net = network2.Network([784, 30, 10], cost=network2.CrossEntropyCost)
net.large_weight_initializer()
net.SGD(training_data, 30, 10, 0.5, evaluation_data=test_data,monitor_evaluation_accuracy=True)
# Out:
# Epoch 0 training complete
# Accuracy on evaluation data: 9031 / 10000
# Epoch 1 training complete
# Accuracy on evaluation data: 9234 / 10000
# Epoch 2 training complete
# Accuracy on evaluation data: 9285 / 10000
# Epoch 3 training complete
# Accuracy on evaluation data: 9359 / 10000
# Epoch 4 training complete
# Accuracy on evaluation data: 9340 / 10000
# Epoch 5 training complete
# Accuracy on evaluation data: 9336 / 10000
# Epoch 6 training complete
# Accuracy on evaluation data: 9366 / 10000
# Epoch 7 training complete
# Accuracy on evaluation data: 9383 / 10000
# Epoch 8 training complete
# Accuracy on evaluation data: 9423 / 10000
# Epoch 9 training complete
# Accuracy on evaluation data: 9401 / 10000
# Epoch 10 training complete
# Accuracy on evaluation data: 9428 / 10000
# Epoch 11 training complete
# Accuracy on evaluation data: 9421 / 10000
# Epoch 12 training complete
# ---------------------------------------------------------------------------
# ...

# %%
# !git clone https://github.com/emms204/neural-networks-and-deep-learning.git
# !python /content/neural-networks-and-deep-learning/main.py /content/neural-networks-and-deep-learning/data/mnist.pkl.gz
# Out:
# fatal: destination path 'neural-networks-and-deep-learning' already exists and is not an empty directory.
# Epoch 0 training complete
# Cost on training data: 0.6155446462992678
# Accuracy on training data: 45536 / 50000
# Cost on evaluation data: 0.7087784294330601
# Accuracy on evaluation data: 9142 / 10000
# Epoch 1 training complete
# Cost on training data: 0.48134078050767864
# Accuracy on training data: 46567 / 50000
# Cost on evaluation data: 0.592427391314789
# Accuracy on evaluation data: 9283 / 10000
# Epoch 2 training complete
# Cost on training data: 0.44778915604224245
# Accuracy on training data: 46780 / 50000
# Cost on evaluation data: 0.5824734191459296
# Accuracy on evaluation data: 9312 / 10000
# Epoch 3 training complete
# Cost on training data: 0.38642897361068157
# Accuracy on training data: 47306 / 50000
# Cost on evaluation data: 0.5201260178647884
# Accuracy on evaluation data: 9414 / 10000
# Epoch 4 training complete
# ...
